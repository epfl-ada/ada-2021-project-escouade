# %% [markdown]
# Each dataset is contained in a gzipped, tab-separated-values (TSV) formatted file in the UTF-8 character set. The first line in each file contains headers that describe what is in each column. A ‘\N’ is used to denote that a particular field is missing or null for that title/name. The available datasets are as follows:
#
# title.akas.tsv.gz - Contains the following information for titles:
#
# - titleId (string) - a tconst, an alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - title (string) – the localized title
# - region (string) - the region for this version of the title
# - language (string) - the language of the title
# - types (array) - Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning
# - attributes (array) - Additional terms to describe this alternative title, not enumerated
# - isOriginalTitle (boolean) – 0: not original title; 1: original title
#
# title.basics.tsv.gz - Contains the following information for titles:
#
# - tconst (string) - alphanumeric unique identifier of the title
# - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - originalTitle (string) - original title, in the original language
# - isAdult (boolean) - 0: non-adult title; 1: adult title
# - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# - endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# - runtimeMinutes – primary runtime of the title, in minutes
# - genres (string array) – includes up to three genres associated with the title
#
# title.crew.tsv.gz – Contains the director and writer information for all the titles in IMDb. Fields include:
#
# - tconst (string) - alphanumeric unique identifier of the title
# - directors (array of nconsts) - director(s) of the given title
# - writers (array of nconsts) – writer(s) of the given title
# - title.episode.tsv.gz – Contains the tv episode information. Fields include:
# - tconst (string) - alphanumeric identifier of episode
# - parentTconst (string) - alphanumeric identifier of the parent TV Series
# - seasonNumber (integer) – season number the episode belongs to
# - episodeNumber (integer) – episode number of the tconst in the TV series
#
# title.principals.tsv.gz – Contains the principal cast/crew for titles
#
# - tconst (string) - alphanumeric unique identifier of the title
# - ordering (integer) – a number to uniquely identify rows for a given titleId
# - nconst (string) - alphanumeric unique identifier of the name/person
# - category (string) - the category of job that person was in
# - job (string) - the specific job title if applicable, else '\N'
# - characters (string) - the name of the character played if applicable, else '\N'
#
# title.ratings.tsv.gz – Contains the IMDb rating and votes information for titles
#
# - tconst (string) - alphanumeric unique identifier of the title
# - averageRating – weighted average of all the individual user ratings
# - numVotes - number of votes the title has received
#
# name.basics.tsv.gz – Contains the following information for names:
#
# - nconst (string) - alphanumeric unique identifier of the name/person
# - primaryName (string)– name by which the person is most often credited
# - birthYear – in YYYY format
# - deathYear – in YYYY format if applicable, else '\N'
# - primaryProfession (array of strings)– the top-3 professions of the person
# - knownForTitles (array of tconsts) – titles the person is known for

# %% [markdown]
# ### Importing datasets

# %%
import pandas as pd
import numpy as np

# %%
principals = './data/title.principals.tsv.gz'
names = './data/name.basics.tsv.gz'
akas = './data/title.akas.tsv.gz'
titles = './data/title.basics.tsv.gz'
crew = './data/title.crew.tsv.gz'
ratings = './data/title.ratings.tsv.gz'

#TODO :
#duplicates ?
#drop columns which would not be used

# %%
df_principals = pd.read_csv(principals, 
            compression = "infer",
            sep = '\t',
            na_values = '\\N')

#df_principals.sample(10)

#check what is self
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-38-8151443addc7> in <module>
# ----> 1 df_principals = pd.read_csv(principals,
#       2             compression = "infer",
#       3             sep = '\t',
#       4             na_values = '\\N')
#       5
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067             new_rows = len(index)
#    1068
# -> 1069         df = DataFrame(col_dict, columns=columns, index=index)
#    1070
#    1071         self._currow += new_rows
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1699     arrays = [x if not isinstance(x, ABCPandasArray) else x.to_numpy() for x in arrays]
#    1700     try:
# -> 1701         blocks = _form_blocks(arrays, names, axes)
#    1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _form_blocks(arrays, names, axes)
#    1788
#    1789     if len(items_dict["ObjectBlock"]) > 0:
# -> 1790         object_blocks = _simple_blockify(items_dict["ObjectBlock"], np.object_)
#    1791         blocks.extend(object_blocks)
#    1792
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _simple_blockify(tuples, dtype)
#    1832     not None, coerce to this dtype
#    1833     """
# -> 1834     values, placement = _stack_arrays(tuples, dtype)
#    1835
#    1836     # TODO: CHECK DTYPE?
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1878     shape = (len(arrays),) + _shape_compat(first)
#    1879
# -> 1880     stacked = np.empty(shape, dtype=dtype)
#    1881     for i, arr in enumerate(arrays):
#    1882         stacked[i] = _asarray_compat(arr)
#
# MemoryError: Unable to allocate 1.77 GiB for an array with shape (5, 47545542) and data type object

# %%
df_names = pd.read_csv(names, 
            compression = "infer",
            sep = '\t',
            na_values = '\\N')

df_names.drop(columns = ['birthYear', 'deathYear'], inplace = True)
#df_names.sample(10)

# %%
df_titles = pd.read_csv(titles, 
            compression = "infer",
            sep = '\t',
            na_values = '\\N')

df_titles.drop(columns = ['isAdult', 'endYear'], inplace = True)            
#df_titles.sample(10)

#drop columns : isAdult, endYear (as we're considering movies ?)
# Out:
# C:\Users\celin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_akas = pd.read_csv(akas, 
            compression = "infer",
            sep = '\t',
            na_values = '\\N')


#df_akas.sample(10)
# Out:
# C:\Users\celin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_crew = pd.read_csv(crew, 
            compression="infer",
            sep = '\t',
            na_values = '\\N')
            
#df_crew.sample(10)

# %%
df_ratings = pd.read_csv(ratings, 
            compression="infer",
            sep = '\t',
            na_values = '\\N')
            
#df_ratings.sample(10)

# %% [markdown]
# ## Modifying and merging the datasets

# %% [markdown]
# Goal here is to transform the dataframe df_principals containing the crew of each movies to a dict object, merge the other dataframes with movies as index and then insert the dict object in a new column named 'crew'. At the end save it as a json file.

# %%
# multiple rows for one movie in df_principals (as there are multiple people involved in the crew), for example : 
df_principals.loc[df_principals['tconst'] == 'tt6726106']
# Out:
#              tconst  ordering     nconst  category       job       characters
# 38848507  tt6726106         1  nm9183136     actor       NaN   ["Lin Yutang"]
# 38848508  tt6726106         2  nm9139744   actress       NaN  ["Ling Chaoxi"]
# 38848509  tt6726106         3  nm8360107   actress       NaN    ["Xia Weiye"]
# 38848510  tt6726106         4  nm6718764   actress       NaN      ["Shen Xi"]
# 38848511  tt6726106         5  nm8885471  director       NaN              NaN
# 38848512  tt6726106         6  nm8364498  producer  producer              NaN
# 38848513  tt6726106         7  nm8658895     actor       NaN   ["He Zhizhou"]
# 38848514  tt6726106         8  nm9393190     actor       NaN       ["Baobao"]

# %%
# changing nconst values by actual names from df_names 
df_principals = df_principals.rename(columns = {'nconst' : 'name'})
df_principals['name'] = df_principals['name'].map(df_names.set_index('nconst')['primaryName'])
df_principals

# managing here NANs
# Out:
#              tconst  ordering                  name         category  \
# 0         tt0000001         1            Carmencita             self
# 1         tt0000001         2  William K.L. Dickson         director
# 2         tt0000001         3         William Heise  cinematographer
# 3         tt0000002         1         Émile Reynaud         director
# 4         tt0000002         2         Gaston Paulin         composer
# ...             ...       ...                   ...              ...
# 47545537  tt9916880         4          Eden Gamliel          actress
# 47545538  tt9916880         5          Hilary Audus         director
# 47545539  tt9916880         6      Lucinda Whiteley           writer
# 47545540  tt9916880         7       Francesca Simon           writer
# 47545541  tt9916880         8           Erica Darby         producer
#
#                               job        characters
# 0                             NaN          ["Self"]
# 1                             NaN               NaN
# 2         director of photography               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
# ...                           ...               ...
# 47545537                      NaN  ["Horrid Henry"]
# 47545538       principal director               NaN
# 47545539                      NaN               NaN
# 47545540                    books               NaN
# 47545541                 producer               NaN
#
# [47545542 rows x 6 columns]

# %%
#preparing the dataframe to be transformed into dict 
df_principals_hier = df_principals.set_index(['tconst', 'ordering'])

# %%
dict = df_principals_hier.to_dict('index')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-35-d833a11b2026> in <module>
# ----> 1 dict = df_principals_hier.to_dict('index')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in to_dict(self, orient, into)
#    1606             if not self.index.is_unique:
#    1607                 raise ValueError("DataFrame index must be unique for orient='index'.")
# -> 1608             return into_c(
#    1609                 (t[0], dict(zip(self.columns, t[1:])))
#    1610                 for t in self.itertuples(name=None)
#
# MemoryError:

# %%
#merging df_crew and df_titles to have a dataframe containing movies and there respective crew
merged = pd.merge(df_titles, df_crew, on = 'tconst')
merged
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8407394  tt9916848  tvEpisode              Episode #3.17
# 8407395  tt9916850  tvEpisode              Episode #3.19
# 8407396  tt9916852  tvEpisode              Episode #3.20
# 8407397  tt9916856      short                   The Wind
# 8407398  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  startYear runtimeMinutes  \
# 0                       Carmencita     1894.0            1.0
# 1           Le clown et ses chiens     1892.0            5.0
# 2                   Pauvre Pierrot     1892.0            4.0
# 3                      Un bon bock     1892.0           12.0
# 4                 Blacksmith Scene     1893.0            1.0
# ...                            ...        ...            ...
# 8407394              Episode #3.17     2010.0            NaN
# 8407395              Episode #3.19     2010.0            NaN
# 8407396              Episode #3.20     2010.0            NaN
# 8407397                   The Wind     2015.0           27.0
# 8407398  Horrid Henry Knows It All     2014.0           10.0
#
#                              genres            directors  \
# 0                 Documentary,Short            nm0005690
# 1                   Animation,Short            nm0721526
# 2          Animation,Comedy,Romance            nm0721526
# 3                   Animation,Short            nm0721526
# 4                      Comedy,Short            nm0005690
# ...                             ...                  ...
# 8407394         Action,Drama,Family  nm5519454,nm5519375
# 8407395         Action,Drama,Family  nm5519454,nm5519375
# 8407396         Action,Drama,Family  nm5519454,nm5519375
# 8407397                       Short           nm10538645
# 8407398  Adventure,Animation,Comedy            nm0996406
#
#                                writers
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 8407394  nm6182221,nm1628284,nm2921377
# 8407395  nm6182221,nm1628284,nm2921377
# 8407396  nm6182221,nm1628284,nm2921377
# 8407397                      nm6951431
# 8407398            nm1482639,nm2586970
#
# [8407399 rows x 9 columns]

# %%
merged['titleType'].unique()
# Out:
# array(['short', 'movie', 'tvEpisode', 'tvSeries', 'tvShort', 'tvMovie',
#        'tvMiniSeries', 'tvSpecial', 'video', 'videoGame', 'tvPilot'],
#       dtype=object)

# %%
#keeping only rows concerning movies
merged.drop(merged.loc[merged['titleType'] !='movie'].index, inplace=True)

print(f'the dataframe contains now {len(merged)} rows')
# Out:
# the dataframe contains now 4206140 rows

# %%
df_principals['crew'] = dict.values()
merged = merged.merge(df_principals, on = 'tconst', how = 'left')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c51fa2e9e8ca> in <module>
#       1 df_principals['crew'] = dict.values()
# ----> 2 merged = merged.merge(df_principals, on = 'tconst', how = 'left')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     691         rindexers = {1: right_indexer} if right_indexer is not None else {}
#     692
# --> 693         result_data = concatenate_block_managers(
#     694             [(self.left._mgr, lindexers), (self.right._mgr, rindexers)],
#     695             axes=[llabels.append(rlabels), join_index],
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\concat.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#      80             b = make_block(values, placement=placement, ndim=blk.ndim)
#      81         else:
# ---> 82             b = make_block(
#      83                 _concatenate_join_units(join_units, concat_axis, copy=copy),
#      84                 placement=placement,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2733     if klass is None:
#    2734         dtype = dtype or values.dtype
# -> 2735         klass = get_block_type(values, dtype)
#    2736
#    2737     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py in get_block_type(values, dtype)
#    2698     elif is_datetime64tz_dtype(values.dtype):
#    2699         cls = DatetimeTZBlock
# -> 2700     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    2701         cls = ObjectValuesExtensionBlock
#    2702     elif is_extension_array_dtype(values.dtype):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\dtypes\common.py in is_interval_dtype(arr_or_dtype)
#     532     if arr_or_dtype is None:
#     533         return False
# --> 534     return IntervalDtype.is_dtype(arr_or_dtype)
#     535
#     536
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\dtypes\dtypes.py in is_dtype(cls, dtype)
#    1136         can match (via string or type)
#    1137         """
# -> 1138         if isinstance(dtype, str):
#    1139             if dtype.lower().startswith("interval"):
#    1140                 try:
#
# KeyboardInterrupt:

# %%
merged.columns = ['tconst', ]
merged.drop(columns = ['ordering', 'name', 'category', 'job', 'characters'])

# %%
merged['crew'][101]
# Out:
# {'name': 'Jørgen Lund',
#  'category': 'actor',
#  'job': nan,
#  'characters': '["Gøngehøvdingen"]'}

# %%
#for i, l in enumerate(merged['directors']):
#    print("list",i,"is",type(l))
## type <str> which is not what we want

# %%
merged['directors'] = '["' + merged['directors'].str.replace(',', '","') + '"]'
merged['directors'] = str(merged['directors'])

# %%
merged['directors'] = merged['directors'].apply(eval)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\celin\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-83-db4c68f5d89b>", line 1, in <module>
#     merged['directors'] = merged['directors'].apply(eval)
#
#   File "C:\Users\celin\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\series.py", line 4138, in apply
#     mapped = lib.map_infer(values, f, convert=convert_dtype)
#
#   File "pandas\_libs\lib.pyx", line 2467, in pandas._libs.lib.map_infer
#
#   File "<string>", line 2
#     1                      ["nm0063413"]
#     ^
# SyntaxError: invalid syntax

# %%
#changing values of directors and writers column based on matching nconst values with df_names
merged['directors'] = merged['directors'].map(df_names.set_index('nconst')['primaryName'])
merged['writers'] = merged['writers'].map(df_names.set_index('nconst')['primaryName'])
merged

#cette technique n'accepte pas les columns avec plusieurs noms
# Out:
#             tconst titleType                    primaryTitle  \
# 0        tt0000502     movie                        Bohemios
# 1        tt0000502     movie                        Bohemios
# 2        tt0000502     movie                        Bohemios
# 3        tt0000502     movie                        Bohemios
# 4        tt0000502     movie                        Bohemios
# ...            ...       ...                             ...
# 4206135  tt9916754     movie  Chico Albuquerque - Revelações
# 4206136  tt9916754     movie  Chico Albuquerque - Revelações
# 4206137  tt9916754     movie  Chico Albuquerque - Revelações
# 4206138  tt9916754     movie  Chico Albuquerque - Revelações
# 4206139  tt9916754     movie  Chico Albuquerque - Revelações
#
#                           originalTitle  startYear runtimeMinutes  \
# 0                              Bohemios     1905.0          100.0
# 1                              Bohemios     1905.0          100.0
# 2                              Bohemios     1905.0          100.0
# 3                              Bohemios     1905.0          100.0
# 4                              Bohemios     1905.0          100.0
# ...                                 ...        ...            ...
# 4206135  Chico Albuquerque - Revelações     2013.0           49.0
# 4206136  Chico Albuquerque - Revelações     2013.0           49.0
# 4206137  Chico Albuquerque - Revelações     2013.0           49.0
# 4206138  Chico Albuquerque - Revelações     2013.0           49.0
# 4206139  Chico Albuquerque - Revelações     2013.0           49.0
#
#               genres         directors writers  ordering  \
# 0                NaN  Ricardo de Baños     NaN       1.0
# 1                NaN  Ricardo de Baños     NaN       2.0
# 2                NaN  Ricardo de Baños     NaN       3.0
# 3                NaN  Ricardo de Baños     NaN       4.0
# 4                NaN  Ricardo de Baños     NaN       5.0
# ...              ...               ...     ...       ...
# 4206135  Documentary               NaN     NaN       5.0
# 4206136  Documentary               NaN     NaN       6.0
# 4206137  Documentary               NaN     NaN       7.0
# 4206138  Documentary               NaN     NaN       8.0
# 4206139  Documentary               NaN     NaN       9.0
#
#                            name         category                   job  \
# 0              Antonio del Pozo            actor                   NaN
# 1                   El Mochuelo            actor                   NaN
# 2              Ricardo de Baños         director                   NaN
# 3            Miguel de Palacios           writer                   NaN
# 4              Guillermo Perrín           writer                   NaN
# ...                         ...              ...                   ...
# 4206135           Angela Gurgel         director  supervising director
# 4206136  Vinicius Augusto Bozzo         director           co-director
# 4206137           Marcelo Alves  cinematographer                   NaN
# 4206138       Wellington Barros  cinematographer                   NaN
# 4206139             Odério Dias  cinematographer                   NaN
#
#         characters                                               crew
# 0              NaN  {'name': 'Antonio del Pozo', 'category': 'acto...
# 1              NaN  {'name': 'El Mochuelo', 'category': 'actor', '...
# 2              NaN  {'name': 'Ricardo de Baños', 'category': 'dire...
# 3              NaN  {'name': 'Miguel de Palacios', 'category': 'wr...
# 4              NaN  {'name': 'Guillermo Perrín', 'category': 'writ...
# ...            ...                                                ...
# 4206135        NaN  {'name': 'Angela Gurgel', 'category': 'directo...
# 4206136        NaN  {'name': 'Vinicius Augusto Bozzo', 'category':...
# 4206137        NaN  {'name': 'Marcelo Alves', 'category': 'cinemat...
# 4206138        NaN  {'name': 'Wellington Barros', 'category': 'cin...
# 4206139        NaN  {'name': 'Odério Dias', 'category': 'cinematog...
#
# [4206140 rows x 15 columns]

# %%
#adding ratings from df_ratings (now we have movies and there title, the crew associated and the ratings)
merged = merged.merge(df_ratings, on = 'tconst', how = 'left')
merged.sample(20)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-89-92be77abe255> in <module>
#       1 #adding ratings from df_ratings (now we have movies and there title, the crew associated and the ratings)
#       2 merged = merged.merge(df_ratings, on = 'tconst', how = 'left')
# ----> 3 merged.sample(20)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5349
#    5350         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
# -> 5351         return self.take(locs, axis=axis)
#    5352
#    5353     @final
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3582         nv.validate_take((), kwargs)
#    3583
# -> 3584         self._consolidate_inplace()
#    3585
#    3586         new_data = self._mgr.take(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5539             self._mgr = self._mgr.consolidate()
#    5540
# -> 5541         self._protect_consolidate(f)
#    5542
#    5543     @final
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5527         """
#    5528         blocks_before = len(self._mgr.blocks)
# -> 5529         result = f()
#    5530         if len(self._mgr.blocks) != blocks_before:
#    5531             self._clear_item_cache()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in f()
#    5537
#    5538         def f():
# -> 5539             self._mgr = self._mgr.consolidate()
#    5540
#    5541         self._protect_consolidate(f)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     986         bm = type(self)(self.blocks, self.axes)
#     987         bm._is_consolidated = False
# --> 988         bm._consolidate_inplace()
#     989         return bm
#     990
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     991     def _consolidate_inplace(self) -> None:
#     992         if not self.is_consolidated():
# --> 993             self.blocks = tuple(_consolidate(self.blocks))
#     994             self._is_consolidated = True
#     995             self._known_consolidated = True
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1914     new_blocks: List[Block] = []
#    1915     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1916         merged_blocks = _merge_blocks(
#    1917             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1918         )
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1937         # combination of those slices is a slice, too.
#    1938         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 1939         new_values = np.vstack([b.values for b in blocks])
#    1940
#    1941         argsort = np.argsort(new_mgr_locs)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 2.35 GiB for an array with shape (18, 17506177) and data type object

# %%
df_akas = df_akas.rename(columns = {'titleId' : 'tconst'})
merged = merged.merge(df_akas, on = 'tconst', how = 'left')
merged
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-88-e7043dc8cf5c> in <module>
#       1 df_akas = df_akas.rename(columns = {'titleId' : 'tconst'})
# ----> 2 merged = merged.merge(df_akas, on = 'tconst')
#       3 merged
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     682             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     683
# --> 684         join_index, left_indexer, right_indexer = self._get_join_info()
#     685
#     686         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     907             )
#     908         else:
# --> 909             (left_indexer, right_indexer) = self._get_join_indexers()
#     910
#     911             if self.right_index:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     885     def _get_join_indexers(self):
#     886         """ return the join indexers """
# --> 887         return get_join_indexers(
#     888             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     889         )
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\reshape\merge.py in get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1439     }[how]
#    1440
# -> 1441     return join_func(lkey, rkey, count, **kwargs)
#    1442
#    1443
#
# pandas\_libs\join.pyx in pandas._libs.join.inner_join()
#
# pandas\_libs\join.pyx in pandas._libs.join._get_result_indexer()
#
# MemoryError: Unable to allocate 2.21 GiB for an array with shape (296324337,) and data type int64
